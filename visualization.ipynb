# %% [markdown]
# # Visualization of the results

# %% [markdown]
# This jupyter notebook is being developed to visualize the results obtained with the HTA tool
#
# Developed by: **Brenda Ferrari**

# %%
import sys
sys.path.append('..')

import pandas as pd
from utils.performance import Performance

# %% [markdown]
# ## Preparation of data
#
# Input data

# %%
dfi = pd.read_csv("input\input.csv", sep=",", index_col=0)
dfi
# Out:
#                                                     classes        \
# name                                           ...
# Nylon 3 - Poly(propiolactam)                   ...  polyamide
# Nylon 6 - Poly(caprolactam)                    ...  polyamide
# Nylon 8 - Polycapryllactam                     ...  polyamide
# Nylon 10 - Poly(decano-10-lactam)              ...  polyamide
# Nylon 11 - Poly(undecano-11-lactam)            ...  polyamide
# ...                                                           ...
# Poly(cyclohexyl alpha-chloroacrylate)          ...  polyvinyl
# Poly(4-cyclohexyl-1-butene)                    ...  polyvinyl
# Poly(3-cyclopentyl-1-propene)                  ...  polyvinyl
# Poly(3-cyclohexyl-1-propene)                   ...  polyvinyl
# Poly(p-phenyl styrene)                         ...  polyvinyl
#
#                                                      monomers                                          \
# name                                           ...
# Nylon 3 - Poly(propiolactam)                   ...  C1CNC1=O                                      ...
# Nylon 6 - Poly(caprolactam)                    ...  O=C1CCCCCN1                                   ...
# Nylon 8 - Polycapryllactam                     ...  O=C1CCCCCCCN1                                 ...
# Nylon 10 - Poly(decano-10-lactam)              ...  NCCCCCCCCCC(=O)O                              ...
# Nylon 11 - Poly(undecano-11-lactam)            ...  NCCCCCCCCCCC(=O)O                             ...
# ...                                                                                               ...
# Poly(cyclohexyl alpha-chloroacrylate)          ...  C=C(Cl)C(=O)OC1CCCCC1                         ...
# Poly(4-cyclohexyl-1-butene)                    ...  C=CCCC1CCCCC1                                 ...
# Poly(3-cyclopentyl-1-propene)                  ...  C=CCC1CCCC1                                   ...
# Poly(3-cyclohexyl-1-propene)                   ...  C=CCC1CCCCC1                                  ...
# Poly(p-phenyl styrene)                         ...  C=Cc2ccc(c1ccccc1)cc2                         ...
#
#                                                                          head_tail
# name                                           ...
# Nylon 3 - Poly(propiolactam)                   ...                O=C([Rn])CCN[Rn]
# Nylon 6 - Poly(caprolactam)                    ...             O=C([Rn])CCCCCN[Rn]
# Nylon 8 - Polycapryllactam                     ...           O=C([Rn])CCCCCCCN[Rn]
# Nylon 10 - Poly(decano-10-lactam)              ...         O=C([Rn])CCCCCCCCCN[Rn]
# Nylon 11 - Poly(undecano-11-lactam)            ...        O=C([Rn])CCCCCCCCCCN[Rn]
# ...                                                                            ...
# Poly(cyclohexyl alpha-chloroacrylate)          ...  O=C(OC1CCCCC1)C(Cl)([Rn])C[Rn]
# Poly(4-cyclohexyl-1-butene)                    ...          [Rn]CC([Rn])CCC1CCCCC1
# Poly(3-cyclopentyl-1-propene)                  ...            [Rn]CC([Rn])CC1CCCC1
# Poly(3-cyclohexyl-1-propene)                   ...           [Rn]CC([Rn])CC1CCCCC1
# Poly(p-phenyl styrene)                         ...  [Rn]CC([Rn])c2ccc(c1ccccc1)cc2
#
# [206 rows x 3 columns]

# %% [markdown]
# output data

# %%
dfo = pd.read_csv("output-directory_1608", sep=",", index_col=0)
dfo
# Out:
#                                                                       monomers_list  \
# name
# Nylon 3 - Poly(propiolactam)                                               C1CNC1=O
# Nylon 6 - Poly(caprolactam)                                             O=C1CCCCCN1
# Nylon 8 - Polycapryllactam                                            O=C1CCCCCCCN1
# Nylon 10 - Poly(decano-10-lactam)                                  NCCCCCCCCCC(=O)O
# Nylon 11 - Poly(undecano-11-lactam)                               NCCCCCCCCCCC(=O)O
# Nylon 12 - Poly(dodecano-12-lactam)                              NCCCCCCCCCCCC(=O)O
# Nylon 4,6 - Poly(tetramethylene adipamide)                  OC(=O)CCCCC(=O)O.NCCCCN
# Nylon 6,6 - Poly(hexamethylene adipamide)                 OC(=O)CCCCC(=O)O.NCCCCCCN
# Nylon 6,9 - Poly(hexamethylene azelamide)              OC(=O)CCCCCCCC(=O)O.NCCCCCCN
# Nylon 6,10 - Poly(hexamethylene sebacamide)           OC(=O)CCCCCCCCC(=O)O.NCCCCCCN
# Nylon 6,12 - Poly(hexamethylene dodecanediamide)    OC(=O)CCCCCCCCCCC(=O)O.NCCCCCCN
# Nylon 10,10 - Poly(decamethylene sebacamide)      OC(=O)CCCCCCCCC(=O)O.NCCCCCCCCCCN
#
#                                                                                   monomers  \
# name
# Nylon 3 - Poly(propiolactam)                                                  ['C1CNC1=O']
# Nylon 6 - Poly(caprolactam)                                                ['O=C1CCCCCN1']
# Nylon 8 - Polycapryllactam                                               ['O=C1CCCCCCCN1']
# Nylon 10 - Poly(decano-10-lactam)                                     ['NCCCCCCCCCC(=O)O']
# Nylon 11 - Poly(undecano-11-lactam)                                  ['NCCCCCCCCCCC(=O)O']
# Nylon 12 - Poly(dodecano-12-lactam)                                 ['NCCCCCCCCCCCC(=O)O']
# Nylon 4,6 - Poly(tetramethylene adipamide)                  ['OC(=O)CCCCC(=O)O', 'NCCCCN']
# Nylon 6,6 - Poly(hexamethylene adipamide)                 ['OC(=O)CCCCC(=O)O', 'NCCCCCCN']
# Nylon 6,9 - Poly(hexamethylene azelamide)              ['OC(=O)CCCCCCCC(=O)O', 'NCCCCCCN']
# Nylon 6,10 - Poly(hexamethylene sebacamide)           ['OC(=O)CCCCCCCCC(=O)O', 'NCCCCCCN']
# Nylon 6,12 - Poly(hexamethylene dodecanediamide)    ['OC(=O)CCCCCCCCCCC(=O)O', 'NCCCCCCN']
# Nylon 10,10 - Poly(decamethylene sebacamide)      ['OC(=O)CCCCCCCCC(=O)O', 'NCCCCCCCCCCN']
#
#                                                   polymer_id  \
# name
# Nylon 3 - Poly(propiolactam)                       polymer_1
# Nylon 6 - Poly(caprolactam)                        polymer_2
# Nylon 8 - Polycapryllactam                         polymer_3
# Nylon 10 - Poly(decano-10-lactam)                  polymer_4
# Nylon 11 - Poly(undecano-11-lactam)                polymer_5
# Nylon 12 - Poly(dodecano-12-lactam)                polymer_6
# Nylon 4,6 - Poly(tetramethylene adipamide)         polymer_7
# Nylon 6,6 - Poly(hexamethylene adipamide)          polymer_8
# Nylon 6,9 - Poly(hexamethylene azelamide)          polymer_9
# Nylon 6,10 - Poly(hexamethylene sebacamide)       polymer_10
# Nylon 6,12 - Poly(hexamethylene dodecanediamide)  polymer_11
# Nylon 10,10 - Poly(decamethylene sebacamide)      polymer_12
#
#                                                                                classes  \
# name
# Nylon 3 - Poly(propiolactam)                                            not recognized
# Nylon 6 - Poly(caprolactam)                                                  polyamide
# Nylon 8 - Polycapryllactam                        error01: Could not recognize mapping
# Nylon 10 - Poly(decano-10-lactam)                                            polyamide
# Nylon 11 - Poly(undecano-11-lactam)                                          polyamide
# Nylon 12 - Poly(dodecano-12-lactam)                                          polyamide
# Nylon 4,6 - Poly(tetramethylene adipamide)                                   polyamide
# Nylon 6,6 - Poly(hexamethylene adipamide)                                    polyamide
# Nylon 6,9 - Poly(hexamethylene azelamide)                                    polyamide
# Nylon 6,10 - Poly(hexamethylene sebacamide)                                  polyamide
# Nylon 6,12 - Poly(hexamethylene dodecanediamide)                             polyamide
# Nylon 10,10 - Poly(decamethylene sebacamide)                                 polyamide
#
#                                                          mechanism  \
# name
# Nylon 3 - Poly(propiolactam)                      polycondensation
# Nylon 6 - Poly(caprolactam)                       polycondensation
# Nylon 8 - Polycapryllactam                        polycondensation
# Nylon 10 - Poly(decano-10-lactam)                   not recognized
# Nylon 11 - Poly(undecano-11-lactam)                 not recognized
# Nylon 12 - Poly(dodecano-12-lactam)               polycondensation
# Nylon 4,6 - Poly(tetramethylene adipamide)        polycondensation
# Nylon 6,6 - Poly(hexamethylene adipamide)         polycondensation
# Nylon 6,9 - Poly(hexamethylene azelamide)         polycondensation
# Nylon 6,10 - Poly(hexamethylene sebacamide)       polycondensation
# Nylon 6,12 - Poly(hexamethylene dodecanediamide)  polycondensation
# Nylon 10,10 - Poly(decamethylene sebacamide)      polycondensation
#
#                                                                                head_tail
# name
# Nylon 3 - Poly(propiolactam)                                         CN([*:1])C([*:2])=O
# Nylon 6 - Poly(caprolactam)                                      O=C([*:2])CCCCCN([*:1])
# Nylon 8 - Polycapryllactam                                     O=C([*:2])CCCCCCCN([*:1])
# Nylon 10 - Poly(decano-10-lactam)                          N([*:1])CCCCCCCCCC([*:2])(=O)
# Nylon 11 - Poly(undecano-11-lactam)                       N([*:1])CCCCCCCCCCC([*:2])(=O)
# Nylon 12 - Poly(dodecano-12-lactam)                      N([*:1])CCCCCCCCCCCC([*:2])(=O)
# Nylon 4,6 - Poly(tetramethylene adipamide)                                not recognized
# Nylon 6,6 - Poly(hexamethylene adipamide)               O=C([*:1])CCCCC(=O)NCCCCCCN[*:2]
# Nylon 6,9 - Poly(hexamethylene azelamide)            O=C([*:1])CCCCCCCC(=O)NCCCCCCN[*:2]
# Nylon 6,10 - Poly(hexamethylene sebacamide)         O=C([*:1])CCCCCCCCC(=O)NCCCCCCN[*:2]
# Nylon 6,12 - Poly(hexamethylene dodecanediamide)  O=C([*:1])CCCCCCCCCCC(=O)NCCCCCCN[*:2]
# Nylon 10,10 - Poly(decamethylene sebacamide)                              not recognized

# %% [markdown]
# ## Check Performance

# %%
perf = Performance(dfi,dfo)

# %%
perf.calculate_performance()
# Out:
# Performance = 3%
# 3

# %% [markdown]
# ## Visualize

# %%
dfo = dfo.reset_index()
dfi = dfi.reset_index()

# %%
from rdkit import Chem
Chem.Draw.MolsToGridImage([Chem.MolFromSmiles(s) for s in dfi["head_tail"][:2]], legends=dfi["name"][:2].to_list(),molsPerRow=1, subImgSize=(500, 400))

# %%
from rdkit import Chem
Chem.Draw.MolsToGridImage([Chem.MolFromSmiles(s) for s in dfo["head_tail"][:2]], legends=dfo["name"][:2].to_list(),molsPerRow=1, subImgSize=(500, 400))
